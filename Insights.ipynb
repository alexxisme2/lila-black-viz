# %%
from IPython.display import Markdown, display

with open("INSIGHTS.md", "r", encoding="utf-8") as f:
    content = f.read()

display(Markdown(content))
# Out:
# # Insights — LILA BLACK Level Designer Analysis
#
# > Fill these in after exploring the data with the tool.
# > Template structure provided — replace placeholders with actual numbers from your analysis.
#
# ---
#
# ## Insight 1: [Title — e.g., "Storm Deaths Cluster in One Corner of AmbroseValley"]
#
# **What caught my eye:**
# [Describe what you noticed — e.g., "The storm death heatmap showed a dense cluster in the northeast quadrant of AmbroseValley, not evenly distributed as expected."]
#
# **Supporting evidence:**
# [Point to specific data — e.g., "X% of all KilledByStorm events fall within pixel bounds [700-1024, 0-300] on the minimap. In contrast, the southwest quadrant has near-zero storm deaths."]
#
# **What this means for the level designer:**
# [Concrete interpretation — e.g., "The storm's path predictably pushes players northeast to southwest, but the northeast corner has insufficient cover/exits, creating a kill funnel that punishes players who loot that area."]
#
# **Actionable items:**
# - [ ] Add an extraction point or cover in the northeast corner
# - [ ] Metric to track improvement: % storm deaths in that zone (target: reduce by 30%)
# - [ ] Consider adjusting storm path direction or speed in that zone
#
# ---
#
# ## Insight 2: [Title — e.g., "Bot Kill Events Disproportionately Concentrated Near Spawn Areas"]
#
# **What caught my eye:**
# [Describe the observation]
#
# **Supporting evidence:**
# [Specific stat or pattern — e.g., "X BotKill events vs Y Kill events total. BotKills are 3x more concentrated in the central grid square than Kill events."]
#
# **What this means for the level designer:**
# [Interpretation and implication]
#
# **Actionable items:**
# - [ ] Action 1
# - [ ] Metric: [what to measure]
# - [ ] Action 2
#
# ---
#
# ## Insight 3: [Title — e.g., "GrandRift Has Significantly Lower Player Traffic — Certain Areas Are Completely Avoided"]
#
# **What caught my eye:**
# [Observation]
#
# **Supporting evidence:**
# [Data — e.g., "Traffic heatmap on GrandRift shows [X]% of position events in [Y]% of the map's area. The northern quadrant has [Z] total position events over 5 days."]
#
# **What this means for the level designer:**
# [Interpretation]
#
# **Actionable items:**
# - [ ] Action 1
# - [ ] Metric: [what to measure]
# - [ ] Action 2
#
# ---
#
# ## How to Generate These Insights
#
# 1. Open the **Heatmaps** tab
# 2. Switch between "Traffic", "Kill Zones", "Death Zones", "Storm Deaths" for each map
# 3. Note where hotspots cluster — and equally, where the map is dead/empty
# 4. Switch to **Player Journeys**, pick a single match, use the timeline slider to watch events unfold
# 5. Check **Stats** tab → Match Summary Table for per-match outliers (very high storm deaths, very short duration, etc.)
